# %%
import numpy as np
import matplotlib.pyplot as plt

f = open("Vc/test3000.bin", "r")
a = np.fromfile(f, dtype=np.uint8)
a = a.reshape((-1,1080,2040))
a.shape
# Out:
# (3001, 1080, 2040)

# %%
plt.imshow(a[2200, :, :], cmap='gray')
